# %% [markdown]
# # Grid Search CV Example

# %% [markdown]
# This notebook contains an example of how the Grid Search CV module can be used to search for the best parameters when generating or optimising a set of rules.
#
# The Grid Search CV process is as follows:
# * Generate k-fold stratified cross validation datasets.
# * Generate unique sets of rule generation/optimisation parameters from the given search space.
# * For each of the training and validation datasets:
#     * Train/optimise a set of rules using each unique set of parameters (using the training dataset).
#     * Use the provided *scorer* to calculate the maximum overall performance of each rule set on the validation dataset.
# * Return the parameters which generated the highest mean overall performance across the validation datasets.

# %% [markdown]
# ## Requirements

# %% [markdown]
# To run, you'll need the following:
#
# * A labelled, processed dataset (nulls imputed, categorical features encoded).

# %% [markdown]
# ----

# %% [markdown]
# ## Import packages

# %%
from iguanas.rule_selection import GridSearchCV, GreedyFilter
from iguanas.rule_generation import RuleGeneratorDT
from iguanas.rule_optimisation import BayesianOptimiser
from iguanas.metrics.classification import FScore, Precision

import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from hyperopt import tpe, anneal

# %% [markdown]
# ## Read in data

# %% [markdown]
# Let's read in some labelled, processed dummy data.

# %%
X_train = pd.read_csv(
    'dummy_data/X_train_gs.csv', 
    index_col='eid'
)
y_train = pd.read_csv(
    'dummy_data/y_train_gs.csv', 
    index_col='eid'
).squeeze()
X_test = pd.read_csv(
    'dummy_data/X_test_gs.csv', 
    index_col='eid'
)
y_test = pd.read_csv(
    'dummy_data/y_test_gs.csv', 
    index_col='eid'
).squeeze()

# %% [markdown]
# ----

# %% [markdown]
# ## Generate rules using *GridSearchCV*

# %% [markdown]
# We can use the *GridSearchCV* class to implement stratifield k-fold cross validation when searching for the best rule generation parameters. **This allows us to find the best rule generation parameters whilst also reducing the likelihood of overfitting.**

# %% [markdown]
# ### Set up class parameters

# %% [markdown]
# We first need to define the search values for each parameter in the provided rule generation class. We define these in a dictionary, where the dictionary keys are the relevant rule generation parameters and the dictionary values are lists of search values for each parameter. The *GridSearchCV* class will then calculate each unique combination of parameter values, and find the set of parameters that produce the best mean overall rule performance across the folds.

# %%
p = Precision()
fs = FScore(beta=1)

# %%
param_grid = {
    'metric': [fs.fit], 
    'n_total_conditions': [1, 4], 
    'tree_ensemble': [
        RandomForestClassifier(n_estimators=5, random_state=0), 
        RandomForestClassifier(n_estimators=15, random_state=0), 
    ],
    'target_feat_corr_types': [None, 'Infer']
}

# %% [markdown]
# Now that we have our search values, we can define the rest of the *GridSearchCV* class parameters. For the *scorer* parameter, we'll use the *GreedyFilter* class to calculate the best combined rule performance for each parameter set & fold.
#
# **Note here that we are splitting the data into 3 folds for training/validation.**
#
# **Please see the class docstring for more information on each parameter**

# %%
scorer = GreedyFilter(
    metric=fs.fit, 
    sorting_metric=p.fit
)

# %%
params = {
    'rule_class': RuleGeneratorDT,
    'param_grid': param_grid,
    'scorer': scorer,
    'cv': 3,
    'num_cores': 2,
    'verbose': 1
}

# %% [markdown]
# ### Instantiate class and run fit method

# %% [markdown]
# Once the parameters have been set, we can run the *.fit()* method to search for the best rule generation parameters.

# %%
gs_cv = GridSearchCV(**params)
# Out:
# 8 unique parameter sets

# %%
gs_cv.fit(
    X=X_train, 
    y=y_train
)
# Out:
# --- Fitting and validating rules using folds ---
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:05<00:00,  4.24it/s]
# --- Re-fitting rules using best parameters on full dataset ---
# --- Filtering rules to give best combined performance ---

# %% [markdown]
# ### Outputs

# %% [markdown]
# See the `Attributes` section in the class docstring for a description of each attribute generated:

# %%
gs_cv.param_results_per_fold.head()
# Out:
#                                                              metric  \
# Fold ParamSetIndex
# 0    0              <bound method FScore.fit of FScore with beta=1>
#      1              <bound method FScore.fit of FScore with beta=1>
#      2              <bound method FScore.fit of FScore with beta=1>
#      3              <bound method FScore.fit of FScore with beta=1>
#      4              <bound method FScore.fit of FScore with beta=1>
#
#                    n_total_conditions  \
# Fold ParamSetIndex
# 0    0                              1
#      1                              1
#      2                              1
#      3                              1
#      4                              4
#
#                                                         tree_ensemble  \
# Fold ParamSetIndex
# 0    0              RandomForestClassifier(n_estimators=5, random_...
#      1              RandomForestClassifier(n_estimators=5, random_...
#      2              (DecisionTreeClassifier(max_depth=4, max_featu...
#      3              (DecisionTreeClassifier(max_depth=4, max_featu...
#      4              RandomForestClassifier(n_estimators=5, random_...
#
#                    target_feat_corr_types  Performance
# Fold ParamSetIndex
# 0    0                               None     0.511278
#      1                              Infer     0.511278
#      2                               None     0.532258
#      3                              Infer     0.532258
#      4                               None     0.614458

# %%
gs_cv.param_results_aggregated.head()
# Out:
#                                                         metric  \
# ParamSetIndex
# 0              <bound method FScore.fit of FScore with beta=1>
# 1              <bound method FScore.fit of FScore with beta=1>
# 2              <bound method FScore.fit of FScore with beta=1>
# 3              <bound method FScore.fit of FScore with beta=1>
# 4              <bound method FScore.fit of FScore with beta=1>
#
#               n_total_conditions  \
# ParamSetIndex
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              4
#
#                                                    tree_ensemble  \
# ParamSetIndex
# 0              RandomForestClassifier(n_estimators=5, random_...
# 1              RandomForestClassifier(n_estimators=5, random_...
# 2              (DecisionTreeClassifier(max_depth=4, max_featu...
# 3              (DecisionTreeClassifier(max_depth=4, max_featu...
# 4              RandomForestClassifier(n_estimators=5, random_...
#
#               target_feat_corr_types  \
# ParamSetIndex
# 0                               None
# 1                              Infer
# 2                               None
# 3                              Infer
# 4                               None
#
#                                               PerformancePerFold  \
# ParamSetIndex
# 0              [0.5112781954887218, 0.35185185185185186, 0.38...
# 1              [0.5112781954887218, 0.35185185185185186, 0.38...
# 2              [0.532258064516129, 0.38961038961038963, 0.402...
# 3              [0.532258064516129, 0.38961038961038963, 0.402...
# 4                   [0.6144578313253012, 0.538860103626943, 0.5]
#
#                MeanPerformance  StdDevPerformance
# ParamSetIndex
# 0                     0.417464           0.068072
# 1                     0.417464           0.068072
# 2                     0.441582           0.064346
# 3                     0.441582           0.064346
# 4                     0.551106           0.047523

# %%
gs_cv.best_score
# Out:
# 0.5829592533675241

# %%
gs_cv.best_params
# Out:
# {'metric': <bound method FScore.fit of FScore with beta=1>,
#  'n_total_conditions': 4,
#  'tree_ensemble': RandomForestClassifier(max_depth=4, n_estimators=15, random_state=0),
#  'target_feat_corr_types': 'Infer'}

# %% [markdown]
# ----

# %% [markdown]
# ## Apply rules to a separate dataset

# %% [markdown]
# Use the *.transform()* method to apply the best performing rules overall to a separate dataset.

# %%
X_rules_test = gs_cv.transform(
    X=X_test, 
    y=y_test, 
    sample_weight=None
)

# %% [markdown]
# ### Outputs

# %% [markdown]
# The *.transform()* method returns a dataframe giving the binary columns of the rules as applied to the given dataset. See the `Attributes` section in the class docstring for a description of each attribute generated:

# %%
gs_cv.rule_descriptions.head()
# Out:
#                         Precision    Recall  PercDataFlagged    Metric  \
# Rule
# RGDT_Rule_20211209_100   0.847826  0.336207         0.010497  0.481481
# RGDT_Rule_20211209_6     0.860465  0.318966         0.009813  0.465409
# RGDT_Rule_20211209_104   0.860465  0.318966         0.009813  0.465409
# RGDT_Rule_20211209_39    0.837838  0.267241         0.008444  0.405229
# RGDT_Rule_20211209_112   0.852941  0.250000         0.007759  0.386667
#
#                                                                     Logic  \
# Rule
# RGDT_Rule_20211209_100  (X['account_number_sum_order_total_per_account...
# RGDT_Rule_20211209_6    (X['account_number_avg_order_total_per_account...
# RGDT_Rule_20211209_104  (X['account_number_sum_order_total_per_account...
# RGDT_Rule_20211209_39   (X['account_number_avg_order_total_per_account...
# RGDT_Rule_20211209_112  (X['account_number_sum_order_total_per_account...
#
#                         nConditions
# Rule
# RGDT_Rule_20211209_100            3
# RGDT_Rule_20211209_6              2
# RGDT_Rule_20211209_104            2
# RGDT_Rule_20211209_39             2
# RGDT_Rule_20211209_112            2

# %%
X_rules_test.head()
# Out:
# Rule                 RGDT_Rule_20211209_100  RGDT_Rule_20211209_6  \
# eid
# 975-8351797-7122581                       0                     0
# 785-6259585-7858053                       0                     0
# 057-4039373-1790681                       0                     0
# 095-5263240-3834186                       0                     0
# 980-3802574-0009480                       0                     0
#
# Rule                 RGDT_Rule_20211209_104  RGDT_Rule_20211209_39  \
# eid
# 975-8351797-7122581                       0                      0
# 785-6259585-7858053                       0                      0
# 057-4039373-1790681                       0                      0
# 095-5263240-3834186                       0                      0
# 980-3802574-0009480                       0                      0
#
# Rule                 RGDT_Rule_20211209_112  RGDT_Rule_20211209_46  \
# eid
# 975-8351797-7122581                       0                      0
# 785-6259585-7858053                       0                      0
# 057-4039373-1790681                       0                      0
# 095-5263240-3834186                       0                      0
# 980-3802574-0009480                       0                      0
#
# Rule                 RGDT_Rule_20211209_31  RGDT_Rule_20211209_121  \
# eid
# 975-8351797-7122581                      0                       0
# 785-6259585-7858053                      0                       0
# 057-4039373-1790681                      0                       0
# 095-5263240-3834186                      0                       0
# 980-3802574-0009480                      0                       0
#
# Rule                 RGDT_Rule_20211209_45  RGDT_Rule_20211209_23  ...  \
# eid                                                                ...
# 975-8351797-7122581                      0                      0  ...
# 785-6259585-7858053                      0                      0  ...
# 057-4039373-1790681                      0                      0  ...
# 095-5263240-3834186                      0                      0  ...
# 980-3802574-0009480                      0                      0  ...
#
# Rule                 RGDT_Rule_20211209_95  RGDT_Rule_20211209_94  \
# eid
# 975-8351797-7122581                      0                      0
# 785-6259585-7858053                      0                      0
# 057-4039373-1790681                      0                      0
# 095-5263240-3834186                      0                      0
# 980-3802574-0009480                      0                      0
#
# Rule                 RGDT_Rule_20211209_16  RGDT_Rule_20211209_88  \
# eid
# 975-8351797-7122581                      0                      0
# 785-6259585-7858053                      0                      0
# 057-4039373-1790681                      0                      0
# 095-5263240-3834186                      0                      0
# 980-3802574-0009480                      0                      0
#
# Rule                 RGDT_Rule_20211209_8  RGDT_Rule_20211209_43  \
# eid
# 975-8351797-7122581                     0                      0
# 785-6259585-7858053                     0                      0
# 057-4039373-1790681                     0                      0
# 095-5263240-3834186                     0                      0
# 980-3802574-0009480                     0                      0
#
# Rule                 RGDT_Rule_20211209_65  RGDT_Rule_20211209_15  \
# eid
# 975-8351797-7122581                      0                      0
# 785-6259585-7858053                      0                      0
# 057-4039373-1790681                      0                      0
# 095-5263240-3834186                      0                      0
# 980-3802574-0009480                      0                      0
#
# Rule                 RGDT_Rule_20211209_41  RGDT_Rule_20211209_30
# eid
# 975-8351797-7122581                      0                      0
# 785-6259585-7858053                      0                      0
# 057-4039373-1790681                      0                      0
# 095-5263240-3834186                      0                      0
# 980-3802574-0009480                      0                      0
#
# [5 rows x 45 columns]

# %% [markdown]
# ----

# %% [markdown]
# ## Optimise rules using *GridSearchCV*

# %% [markdown]
# We can use the *GridSearchCV* class to implement stratifield k-fold cross validation when searching for the best rule optimisation parameters. **This allows us to find the best rule optimisation parameters whilst also reducing the likelihood of overfitting.**

# %% [markdown]
# ### Set up class parameters

# %% [markdown]
# We firstly need to define the search values for each parameter in the provided rule optimisation class. We define these in a dictionary, where the dictionary keys are the relevant rule optimisation parameters and the dictionary values are lists of search values for each parameter. The *GridSearchCV* class will then calculate each unique combination of parameter values, and find the set of parameters that produce the best mean overall rule performance across the folds.

# %%
f0dot5 = FScore(beta=0.5)
f1 = FScore(beta=1)

# %% [markdown]
# In this example, we'll optimise the rules we generated in the previous Grid Search exercise. To do this, we need to convert the generated rules into the standard Iguanas lambda expression format:

# %%
rule_lambdas = gs_cv.as_rule_lambdas(
    as_numpy=False, 
    with_kwargs=True
)
lambda_kwargs = gs_cv.lambda_kwargs

# %%
param_grid = {
    'rule_lambdas': [rule_lambdas],
    'lambda_kwargs': [lambda_kwargs],
    'metric': [f0dot5.fit, f1.fit],
    'n_iter': [30],
    'algorithm': [tpe.suggest, anneal.suggest],
    'verbose': [0]
}

# %% [markdown]
# Now that we have our search values, we can define the rest of the *GridSearchCV* class parameters. For the *scorer* parameter, we'll use the *GreedyFilter* class to calculate the best combined rule performance for each parameter set & fold.
#
# **Note here that we are splitting the data into 3 folds for training/validation.**
#
# **Please see the class docstring for more information on each parameter**

# %%
scorer = GreedyFilter(
    metric=fs.fit, 
    sorting_metric=p.fit
)

# %%
params = {
    'rule_class': BayesianOptimiser,
    'param_grid': param_grid,
    'scorer': scorer,
    'cv': 3,
    'num_cores': 2,
    'verbose': 1
}

# %% [markdown]
# ### Instantiate class and run fit method

# %% [markdown]
# Once the parameters have been set, we can run the *.fit()* method to search for the best rule optimisation parameters.

# %%
gs_cv = GridSearchCV(**params)
# Out:
# 4 unique parameter sets

# %%
gs_cv.fit(
    X=X_train, 
    y=y_train
)
# Out:
# --- Fitting and validating rules using folds ---
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:18<00:00,  1.53s/it]
# --- Re-fitting rules using best parameters on full dataset ---
# --- Filtering rules to give best combined performance ---

# %% [markdown]
# ### Outputs

# %% [markdown]
# See the `Attributes` section in the class docstring for a description of each attribute generated:

# %%
gs_cv.param_results_per_fold.head()
# Out:
#                                                          rule_lambdas  \
# Fold ParamSetIndex
# 0    0              {'RGDT_Rule_20211209_100': <function _ConvertR...
#      1              {'RGDT_Rule_20211209_100': <function _ConvertR...
#      2              {'RGDT_Rule_20211209_100': <function _ConvertR...
#      3              {'RGDT_Rule_20211209_100': <function _ConvertR...
# 1    0              {'RGDT_Rule_20211209_100': <function _ConvertR...
#
#                                                         lambda_kwargs  \
# Fold ParamSetIndex
# 0    0              {'RGDT_Rule_20211209_100': {'account_number_su...
#      1              {'RGDT_Rule_20211209_100': {'account_number_su...
#      2              {'RGDT_Rule_20211209_100': {'account_number_su...
#      3              {'RGDT_Rule_20211209_100': {'account_number_su...
# 1    0              {'RGDT_Rule_20211209_100': {'account_number_su...
#
#                                                                metric n_iter  \
# Fold ParamSetIndex
# 0    0              <bound method FScore.fit of FScore with beta=0.5>     30
#      1              <bound method FScore.fit of FScore with beta=0.5>     30
#      2                <bound method FScore.fit of FScore with beta=1>     30
#      3                <bound method FScore.fit of FScore with beta=1>     30
# 1    0              <bound method FScore.fit of FScore with beta=0.5>     30
#
#                                                algorithm verbose  Performance
# Fold ParamSetIndex
# 0    0              <function suggest at 0x7f99f8ec4e50>       0     0.608108
#      1              <function suggest at 0x7f99f8ed6670>       0     0.614379
#      2              <function suggest at 0x7f99f8ec4e50>       0     0.574586
#      3              <function suggest at 0x7f99f8ed6670>       0     0.633803
# 1    0              <function suggest at 0x7f99f8ec4e50>       0     0.546763

# %%
gs_cv.param_results_aggregated.head()
# Out:
#                                                     rule_lambdas  \
# ParamSetIndex
# 0              {'RGDT_Rule_20211209_100': <function _ConvertR...
# 1              {'RGDT_Rule_20211209_100': <function _ConvertR...
# 2              {'RGDT_Rule_20211209_100': <function _ConvertR...
# 3              {'RGDT_Rule_20211209_100': <function _ConvertR...
#
#                                                    lambda_kwargs  \
# ParamSetIndex
# 0              {'RGDT_Rule_20211209_100': {'account_number_su...
# 1              {'RGDT_Rule_20211209_100': {'account_number_su...
# 2              {'RGDT_Rule_20211209_100': {'account_number_su...
# 3              {'RGDT_Rule_20211209_100': {'account_number_su...
#
#                                                           metric n_iter  \
# ParamSetIndex
# 0              <bound method FScore.fit of FScore with beta=0.5>     30
# 1              <bound method FScore.fit of FScore with beta=0.5>     30
# 2                <bound method FScore.fit of FScore with beta=1>     30
# 3                <bound method FScore.fit of FScore with beta=1>     30
#
#                                           algorithm verbose  \
# ParamSetIndex
# 0              <function suggest at 0x7f99f8ec4e50>       0
# 1              <function suggest at 0x7f99f8ed6670>       0
# 2              <function suggest at 0x7f99f8ec4e50>       0
# 3              <function suggest at 0x7f99f8ed6670>       0
#
#                                               PerformancePerFold  \
# ParamSetIndex
# 0              [0.608108108108108, 0.5467625899280575, 0.5350...
# 1              [0.6143790849673203, 0.562962962962963, 0.5323...
# 2              [0.574585635359116, 0.5454545454545454, 0.5362...
# 3              [0.6338028169014086, 0.5735294117647058, 0.549...
#
#                MeanPerformance  StdDevPerformance
# ParamSetIndex
# 0                     0.563301           0.032043
# 1                     0.569905           0.033836
# 2                     0.552091           0.016346
# 3                     0.585451           0.035624

# %%
gs_cv.best_score
# Out:
# 0.5854506121697506

# %%
gs_cv.best_params
# Out:
# {'rule_lambdas': {'RGDT_Rule_20211209_100': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_104': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_6': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_39': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_31': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_112': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_121': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_46': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_45': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_23': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_11': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_22': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_128': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_114': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_127': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_113': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_150': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_141': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_44': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_60': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_52': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_10': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_59': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_140': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_117': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_55': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_36': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_78': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_77': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_64': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_18': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_95': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_94': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_96': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_16': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_79': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_75': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_9': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_88': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_43': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_8': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_15': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_41': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_65': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>,
#   'RGDT_Rule_20211209_30': <function iguanas.rules._convert_rule_dicts_to_rule_strings._ConvertRuleDictsToRuleStrings._convert_to_lambda.<locals>._make_lambda.<locals>.<lambda>(**kwargs)>},
#  'lambda_kwargs': {'RGDT_Rule_20211209_100': {'account_number_sum_order_total_per_account_number_1day': 373.625,
#    'account_number_sum_order_total_per_account_number_90day': 259.27},
#   'RGDT_Rule_20211209_104': {'account_number_sum_order_total_per_account_number_1day': 421.565},
#   'RGDT_Rule_20211209_6': {'account_number_avg_order_total_per_account_number_1day': 421.565},
#   'RGDT_Rule_20211209_39': {'account_number_avg_order_total_per_account_number_7day': 572.83499},
#   'RGDT_Rule_20211209_31': {'account_number_avg_order_total_per_account_number_7day': 182.95},
#   'RGDT_Rule_20211209_112': {'account_number_sum_order_total_per_account_number_1day': 618.095},
#   'RGDT_Rule_20211209_121': {'account_number_sum_order_total_per_account_number_30day': 622.595},
#   'RGDT_Rule_20211209_46': {'account_number_avg_order_total_per_account_number_7day': 616.14749},
#   'RGDT_Rule_20211209_45': {'account_number_avg_order_total_per_account_number_7day': 616.14749},
#   'RGDT_Rule_20211209_23': {'account_number_avg_order_total_per_account_number_30day': 616.14749},
#   'RGDT_Rule_20211209_11': {'account_number_avg_order_total_per_account_number_1day': 916.82501},
#   'RGDT_Rule_20211209_22': {'account_number_avg_order_total_per_account_number_30day': 616.14749,
#    'account_number_sum_order_total_per_account_number_90day': 916.82501},
#   'RGDT_Rule_20211209_128': {'account_number_sum_order_total_per_account_number_30day': 916.82501},
#   'RGDT_Rule_20211209_114': {'account_number_sum_order_total_per_account_number_1day': 916.82501},
#   'RGDT_Rule_20211209_127': {'account_number_sum_order_total_per_account_number_30day': 916.82501},
#   'RGDT_Rule_20211209_113': {'account_number_sum_order_total_per_account_number_1day': 916.82501},
#   'RGDT_Rule_20211209_150': {'account_number_sum_order_total_per_account_number_90day': 916.82501},
#   'RGDT_Rule_20211209_141': {'account_number_sum_order_total_per_account_number_7day': 916.82501},
#   'RGDT_Rule_20211209_44': {'account_number_avg_order_total_per_account_number_7day': 616.14749,
#    'account_number_sum_order_total_per_account_number_1day': 927.45001},
#   'RGDT_Rule_20211209_60': {'account_number_avg_order_total_per_account_number_90day': 966.82501,
#    'account_number_sum_order_total_per_account_number_30day': 622.595},
#   'RGDT_Rule_20211209_52': {'account_number_avg_order_total_per_account_number_7day': 971.565,
#    'account_number_avg_order_total_per_account_number_90day': 966.82501,
#    'account_number_sum_order_total_per_account_number_30day': 622.595},
#   'RGDT_Rule_20211209_10': {'account_number_avg_order_total_per_account_number_1day': 916.82501},
#   'RGDT_Rule_20211209_59': {'account_number_avg_order_total_per_account_number_90day': 916.82501},
#   'RGDT_Rule_20211209_140': {'account_number_sum_order_total_per_account_number_7day': 916.82501,
#    'account_number_sum_order_total_per_account_number_90day': 971.565},
#   'RGDT_Rule_20211209_117': {'account_number_sum_order_total_per_account_number_1day': 971.565,
#    'account_number_sum_order_total_per_account_number_90day': 916.82501},
#   'RGDT_Rule_20211209_55': {'account_number_avg_order_total_per_account_number_90day': 225.18999,
#    'account_number_num_distinct_transaction_per_account_number_1day': 2.0,
#    'account_number_sum_order_total_per_account_number_30day': 957.375},
#   'RGDT_Rule_20211209_36': {'account_number_avg_order_total_per_account_number_7day': 265.78751,
#    'account_number_num_order_items_per_account_number_1day': 4.0},
#   'RGDT_Rule_20211209_78': {'account_number_num_order_items_per_account_number_1day': 4.0,
#    'account_number_sum_order_total_per_account_number_7day': 957.375},
#   'RGDT_Rule_20211209_77': {'account_number_num_order_items_per_account_number_1day': 4.0,
#    'account_number_sum_order_total_per_account_number_1day': 957.375},
#   'RGDT_Rule_20211209_64': {'account_number_num_distinct_transaction_per_account_number_1day': 3.0,
#    'account_number_sum_order_total_per_account_number_7day': 916.82501,
#    'account_number_sum_order_total_per_account_number_90day': 957.375},
#   'RGDT_Rule_20211209_18': {'account_number_avg_order_total_per_account_number_30day': 230.36,
#    'account_number_num_order_items_per_account_number_7day': 4.0,
#    'account_number_sum_order_total_per_account_number_7day': 1241.85498},
#   'RGDT_Rule_20211209_95': {'account_number_sum_order_total_per_account_number_1day': 1413.84998},
#   'RGDT_Rule_20211209_94': {'account_number_sum_order_total_per_account_number_1day': 1407.375,
#    'account_number_sum_order_total_per_account_number_7day': 957.375},
#   'RGDT_Rule_20211209_96': {'account_number_sum_order_total_per_account_number_1day': 1445.32501,
#    'account_number_sum_order_total_per_account_number_90day': 916.82501},
#   'RGDT_Rule_20211209_16': {'account_number_avg_order_total_per_account_number_30day': 230.36,
#    'account_number_num_distinct_transaction_per_account_number_1day': 3.0,
#    'account_number_num_order_items_per_account_number_7day': 4.0,
#    'account_number_sum_order_total_per_account_number_7day': 1241.85498},
#   'RGDT_Rule_20211209_79': {'account_number_num_order_items_per_account_number_1day': 5.0,
#    'account_number_num_order_items_per_account_number_lifetime': 5.0,
#    'account_number_sum_order_total_per_account_number_1day': 957.375,
#    'account_number_sum_order_total_per_account_number_30day': 916.82501},
#   'RGDT_Rule_20211209_75': {'account_number_num_distinct_transaction_per_account_number_90day': 4.0,
#    'account_number_num_order_items_per_account_number_lifetime': 4.0,
#    'account_number_sum_order_total_per_account_number_30day': 916.82501},
#   'RGDT_Rule_20211209_9': {'account_number_avg_order_total_per_account_number_1day': 916.82501,
#    'account_number_sum_order_total_per_account_number_30day': 1063.53003},
#   'RGDT_Rule_20211209_88': {'account_number_num_order_items_per_account_number_7day': 7.0},
#   'RGDT_Rule_20211209_43': {'account_number_avg_order_total_per_account_number_7day': 616.14749,
#    'account_number_num_distinct_transaction_per_account_number_30day': 2.0},
#   'RGDT_Rule_20211209_8': {'account_number_avg_order_total_per_account_number_1day': 916.82501,
#    'account_number_num_order_items_per_account_number_lifetime': 3.0},
#   'RGDT_Rule_20211209_15': {'account_number_avg_order_total_per_account_number_30day': 1562.48999,
#    'account_number_sum_order_total_per_account_number_7day': 623.125,
#    'num_order_items': 3.0},
#   'RGDT_Rule_20211209_41': {'account_number_avg_order_total_per_account_number_7day': 616.14749,
#    'account_number_avg_order_total_per_account_number_90day': 1123.36505,
#    'account_number_num_order_items_per_account_number_30day': 3.0},
#   'RGDT_Rule_20211209_65': {'account_number_num_distinct_transaction_per_account_number_1day': 4.0,
#    'account_number_sum_order_total_per_account_number_7day': 623.125,
#    'num_order_items': 3.0},
#   'RGDT_Rule_20211209_30': {'account_number_avg_order_total_per_account_number_7day': 1577.02002,
#    'account_number_sum_order_total_per_account_number_1day': 916.82501}},
#  'metric': <bound method FScore.fit of FScore with beta=1>,
#  'n_iter': 30,
#  'algorithm': <function hyperopt.anneal.suggest(new_ids, domain, trials, seed, *args, **kwargs)>,
#  'verbose': 0}

# %% [markdown]
# ----

# %% [markdown]
# ## Apply rules to a separate dataset

# %% [markdown]
# Use the *.transform()* method to apply the best performing rules overall to a separate dataset.

# %%
X_rules_test = gs_cv.transform(
    X=X_test, 
    y=y_test, 
    sample_weight=None
)

# %% [markdown]
# ### Outputs

# %% [markdown]
# The *.transform()* method returns a dataframe giving the binary columns of the rules as applied to the given dataset. See the `Attributes` section in the class docstring for a description of each attribute generated:

# %%
gs_cv.rule_descriptions.head()
# Out:
#                         Precision    Recall  PercDataFlagged    Metric  \
# Rule
# RGDT_Rule_20211209_100   0.847826  0.336207         0.010497  0.481481
# RGDT_Rule_20211209_22    0.857143  0.310345         0.009585  0.455696
# RGDT_Rule_20211209_44    0.857143  0.310345         0.009585  0.455696
# RGDT_Rule_20211209_60    0.857143  0.310345         0.009585  0.455696
# RGDT_Rule_20211209_9     0.857143  0.310345         0.009585  0.455696
#
#                                                                     Logic  \
# Rule
# RGDT_Rule_20211209_100  (X['account_number_sum_order_total_per_account...
# RGDT_Rule_20211209_22   (X['account_number_avg_order_total_per_account...
# RGDT_Rule_20211209_44   (X['account_number_avg_order_total_per_account...
# RGDT_Rule_20211209_60   (X['account_number_avg_order_total_per_account...
# RGDT_Rule_20211209_9    (X['account_number_avg_order_total_per_account...
#
#                         nConditions
# Rule
# RGDT_Rule_20211209_100            3
# RGDT_Rule_20211209_22             3
# RGDT_Rule_20211209_44             3
# RGDT_Rule_20211209_60             3
# RGDT_Rule_20211209_9              3

# %%
X_rules_test.head()
# Out:
# Rule                 RGDT_Rule_20211209_100  RGDT_Rule_20211209_22  \
# eid
# 975-8351797-7122581                       0                      0
# 785-6259585-7858053                       0                      0
# 057-4039373-1790681                       0                      0
# 095-5263240-3834186                       0                      0
# 980-3802574-0009480                       0                      0
#
# Rule                 RGDT_Rule_20211209_44  RGDT_Rule_20211209_60  \
# eid
# 975-8351797-7122581                      0                      0
# 785-6259585-7858053                      0                      0
# 057-4039373-1790681                      0                      0
# 095-5263240-3834186                      0                      0
# 980-3802574-0009480                      0                      0
#
# Rule                 RGDT_Rule_20211209_9  RGDT_Rule_20211209_52  \
# eid
# 975-8351797-7122581                     0                      0
# 785-6259585-7858053                     0                      0
# 057-4039373-1790681                     0                      0
# 095-5263240-3834186                     0                      0
# 980-3802574-0009480                     0                      0
#
# Rule                 RGDT_Rule_20211209_31  RGDT_Rule_20211209_141  \
# eid
# 975-8351797-7122581                      0                       0
# 785-6259585-7858053                      0                       0
# 057-4039373-1790681                      0                       0
# 095-5263240-3834186                      0                       0
# 980-3802574-0009480                      0                       0
#
# Rule                 RGDT_Rule_20211209_140  RGDT_Rule_20211209_150  \
# eid
# 975-8351797-7122581                       0                       0
# 785-6259585-7858053                       0                       0
# 057-4039373-1790681                       0                       0
# 095-5263240-3834186                       0                       0
# 980-3802574-0009480                       0                       0
#
# Rule                 RGDT_Rule_20211209_113  RGDT_Rule_20211209_117  \
# eid
# 975-8351797-7122581                       0                       0
# 785-6259585-7858053                       0                       0
# 057-4039373-1790681                       0                       0
# 095-5263240-3834186                       0                       0
# 980-3802574-0009480                       0                       0
#
# Rule                 RGDT_Rule_20211209_41  RGDT_Rule_20211209_64  \
# eid
# 975-8351797-7122581                      0                      0
# 785-6259585-7858053                      0                      0
# 057-4039373-1790681                      0                      0
# 095-5263240-3834186                      0                      0
# 980-3802574-0009480                      0                      0
#
# Rule                 RGDT_Rule_20211209_16  RGDT_Rule_20211209_43
# eid
# 975-8351797-7122581                      0                      0
# 785-6259585-7858053                      0                      0
# 057-4039373-1790681                      0                      0
# 095-5263240-3834186                      0                      0
# 980-3802574-0009480                      0                      0

# %% [markdown]
# ----
